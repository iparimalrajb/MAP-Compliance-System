# %%
import pandas as pd

# %%
df=pd.read_excel("Seller_Mapping_Table.xlsx")

# %%
df.count()
# Out:
# Ssellers_name          903
# homologated_sellers    903
# dtype: int64

# %%
df.rename(columns={"Ssellers_name":"Seller_name","homologated_sellers":"Homologated_sellers_name"})
# Out:
#                     Seller_name      Homologated_sellers_name
# 0                Cocoblu Retail           BJ's Wholesale Club
# 1      RK World Infocom Pvt Ltd                American Eagle
# 2    Appario Retail Private Ltd                      Tapestry
# 3              RetailEZ Pvt Ltd           Wakefern / ShopRite
# 4                 ETrade Online          Harbor Freight Tools
# ..                          ...                           ...
# 898            Hydroshell India  Barnes and Noble Booksellers
# 899                 KT FASHIONS           J.C. Penney Company
# 900               Shoplite 0000                      Tapestry
# 901                 Bestbuybook        Sprouts Farmers Market
# 902                  Seetabooks                  Advance Auto
#
# [903 rows x 2 columns]

# %%
df=df.rename(columns={"Ssellers_name":"Seller_name","homologated_sellers":"Homologated_sellers_name"})

# %%
Sellers_mapping_table_cleaned=df[["Seller_name","Homologated_sellers_name"]]

# %%
Sellers_mapping_table_cleaned.to_csv("Sellers_Mapping_Table_Cleaned.csv", index=False)
