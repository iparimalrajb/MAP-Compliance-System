# %%
import pandas as pd

# %%
df=pd.read_xml("SKU_Table.xml")

# %%
df.head()
# Out:
#         PN      Sku
# 0  Pib01a1  0X749QB
# 1  Pib01a2  75X62BB
# 2  Pib01a3   DF627B
# 3  Pib01a4   4ZB96A
# 4  Pib01a5  0R0N0QB

# %%
df.rename(columns={"PN":"Product_Number","Sku":"SKU"}, inplace=True)

# %%
SKU_Table_cleaned=df[["Product_Number","SKU"]]

# %%
SKU_Table_cleaned.to_csv("SKU_Table_Cleaned.csv", index=False)
